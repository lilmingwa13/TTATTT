# %% [markdown]
# # Câu 27

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

def gcd(a, b):
    while b:
        a, b = b, a % b
    return a

def pairs():
    pairs = []
    for a in range(2, 1000):
        for b in range(a + 1, 1000):
            if is_prime(gcd(a, b)):
                pairs.append((a,b))
    return pairs

if __name__ == '__main__':
    pairs = pairs()
    for i in pairs:
        print(i)
# Out:
# (2, 4)
# (2, 6)
# (2, 8)
# (2, 10)
# (2, 12)
# (2, 14)
# (2, 16)
# (2, 18)
# (2, 20)
# (2, 22)
# (2, 24)
# (2, 26)
# (2, 28)
# (2, 30)
# (2, 32)
# (2, 34)
# (2, 36)
# (2, 38)
# (2, 40)
# (2, 42)
# (2, 44)
# (2, 46)
# (2, 48)
# (2, 50)
# (2, 52)
# (2, 54)
# (2, 56)
# (2, 58)
# (2, 60)
# (2, 62)
# (2, 64)
# (2, 66)
# (2, 68)
# (2, 70)
# (2, 72)
# (2, 74)
# (2, 76)
# (2, 78)
# (2, 80)
# (2, 82)
# (2, 84)
# (2, 86)
# (2, 88)
# (2, 90)
# (2, 92)
# (2, 94)
# (2, 96)
# (2, 98)
# (2, 100)
# (2, 102)
# (2, 104)
# (2, 106)
# (2, 108)
# (2, 110)
# (2, 112)
# (2, 114)
# (2, 116)
# (2, 118)
# (2, 120)
# (2, 122)
# (2, 124)
# (2, 126)
# (2, 128)
# (2, 130)
# (2, 132)
# (2, 134)
# (2, 136)
# (2, 138)
# (2, 140)
# (2, 142)
# (2, 144)
# (2, 146)
# (2, 148)
# (2, 150)
# (2, 152)
# (2, 154)
# (2, 156)
# (2, 158)
# (2, 160)
# (2, 162)
# (2, 164)
# (2, 166)
# (2, 168)
# (2, 170)
# (2, 172)
# (2, 174)
# (2, 176)
# (2, 178)
# (2, 180)
# (2, 182)
# (2, 184)
# (2, 186)
# (2, 188)
# (2, 190)
# (2, 192)
# ...

# %% [markdown]
# # Câu 28

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

def gcd(a, b):
    while b > 0:
        a, b = b, a % b
    return a

def is_carmichael(n):
    if is_prime(n):
        return False
    for b in range(2, n):
        if gcd(b, n) == 1:
            if nhan_bpl(b, n - 1, n) != 1:
                return False
    return True

def find_carmichaels(N):
    carmichaels = []
    for i in range(2, N):
        if is_carmichael(i):
            carmichaels.append(i)
    return carmichaels

        
def nhan_bpl(a, k, n):
    b = 1
    A = a % n

    while k > 0:
        if k & 1 == 1:
            b = b * A % n
        k >>= 1
        A = A * A % n

    return b

if __name__ == '__main__':
    try:
        N = int(input("Nhập số nguyên N: "))
        if not 0 <= N <= 10000:
            raise ValueError("Không hợp lệ!")
        carmichaels = find_carmichaels(N)
        if not carmichaels:
            print(f"Không có số carmhichael nhỏ hơn {N}!")
        else:
            print(f"Số carmichael nhỏ hơn {N} là: {carmichaels}")
    except ValueError as e:
        print(e)
# Out:
# Số carmichael nhỏ hơn 6605 là: [561, 1105, 1729, 2465, 2821, 6601]

# %% [markdown]
# # Câu 29

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

def gcd(a, b):
    while b > 0:
        a, b = b, a % b
    return a

def is_carmichael(n):
    if is_prime(n):
        return False
    for b in range(2, n):
        if gcd(b, n) == 1:
            if nhan_bpl(b, n - 1, n) != 1:
                return False
    return True

def find_carmichaels(N):
    carmichaels = []
    for i in range(2, N):
        if is_carmichael(i):
            carmichaels.append(i)
    return carmichaels

        
def nhan_bpl(a, k, n):
    b = 1
    A = a % n

    while k > 0:
        if k & 1 == 1:
            b = b * A % n
        k >>= 1
        A = A * A % n
    return b

def count_carmichaels(N):
    carmichaels = 0
    for i in range(2, N):
        if is_carmichael(i):
            carmichaels += 1
    return carmichaels

if __name__ == '__main__':
    try:
        N = int(input("Nhập số nguyên N: "))
        if not 0 <= N <= 10000:
            raise ValueError("Không hợp lệ!")
        carmichaels = count_carmichaels(N)
        print("Số số carmichael: ", carmichaels)
    except ValueError as e:
        print(e)
# Out:
# Số số carmichael:  1

# %% [markdown]
# # Câu 30

# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

def gcd(a, b):
    while b > 0:
        a, b = b, a % b
    return a

def is_carmichael(n):
    if is_prime(n):
        return False
    for b in range(2, n):
        if gcd(b, n) == 1:
            if nhan_bpl(b, n - 1, n) != 1:
                return False
    return True

def nhan_bpl(a, k, n):
    b = 1
    A = a % n

    while k > 0:
        if k & 1 == 1:
            b = b * A % n
        k >>= 1
        A = A * A % n
    return b

def sum_carmichaels(N):
    carmichaels = 0
    for i in range(2, N):
        if is_carmichael(i):
            carmichaels += i
    return carmichaels

if __name__ == '__main__':
    try:
        N = int(input("Nhập số nguyên N: "))
        if not 0 <= N <= 10000:
            raise ValueError("Không hợp lệ!")
        carmichaels = sum_carmichaels(N)
        print("Tổng số carmichael: ", carmichaels)
    except ValueError as e:
        print(e)
# Out:
# Tổng số carmichael:  0

# %% [markdown]
# # Câu 31

# %%
#Câu 31 (chạy testcase 8/10)
def is_prime(num):
    if num <= 1:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

def find_closest_prime(n):
    if n <= 1:
        return 2
    if n == 2:
        return 3

    lower_prime = n - 1
    while not is_prime(lower_prime):
        lower_prime -= 1

    higher_prime = n + 1
    while not is_prime(higher_prime):
        higher_prime += 1

    return lower_prime if n - lower_prime <= higher_prime - n else higher_prime

def nhan_bpl(a, k, n):
    b = 1
    A = a % n

    while k:
        if k & 1 == 1:
            b = (b * A) % n
        k >>= 1
        A = (A * A) % n
    return b
        
if __name__ == '__main__':
    try:
        a = int(input("Nhập a: "))
        if a < 0: 
            raise ValueError("Không hợp lệ!")
        k = find_closest_prime(a)
        print(f"k = {k}")
        print(f"a^k mod n = {a}^{k} mod 123456 = {nhan_bpl(a, k, 123456)}")
    except ValueError as e:
        print(e)
# Out:
# k = 7
# a^k mod n = 9^7 mod 123456 = 91641

# %% [markdown]
# # Câu 32

# %%
from random import *
def gcd(a, b):
    while b:
        a, b = b, a % b
    return a

def nghichdao(a, p):
    
    u = a
    v = p
    x1 = 1
    x2 = 0
    
    while u != 1:
        q = v // u
        r = v - q * u
        x = x2 - q * x1
        v = u
        u = r
        x2 = x1
        x1 = x
    
    if x1 < 0:
        x1 = x1 + p
    
    return x1

def nhan_bpl(a, k, n):
    b = 1
    A = a % n 

    while k:
        if k & 1 == 1:
            b = b * A % n
        k >>= 1
        A = A * A % n
    return b


def find_s_r(n):
    n -= 1
    s = 0
    while(n % 2 == 0):
        n //= 2
        s += 1
    r = n
    return s, r
def is_prime_miller_rabin(n, t):
    if n < 2:
        return False
    if n == 2:
        return True
    if n % 2 == 0:
        return False
    
    s, r = find_s_r(n)
    for i in range(t):
        a = randint(2, n - 1)
        y =  nhan_bpl(a, r, n)
        if y != 1 and y != n - 1:
            j = 1
            while j <= 𝑠 - 1 and y != n - 1:
                y = y ** 2 % n
                if y == 1:
                    return False
                j += 1
            if y != n - 1 :
                return False
    return True


if __name__ == '__main__':
    
    while True:
        p = randint(100 + 1, 500 - 1)
        q = randint(100 + 1, 500 - 1)
        if is_prime_miller_rabin(p, 10) and is_prime_miller_rabin(q, 10):
            break;
    
    print(p, q)
    
    print(f"p = {p}, q = {q}")
    
    n = p * q
    U = (p - 1)*(q - 1)
    print(f"n = {n}")
    print(f"U = {U}")
    
    e = randint(2, U - 1)
    
    while gcd(e, U) != 1:
        e = randint(2, U - 1)
    print(f"e = {e}")
    d = nghichdao(e, U)
    print(f"d = {d}")
    try: 
        SBD = int(input("Nhập SBD: "))
        if SBD < 0: 
             raise ValueError("Không hợp lệ!")
        m = SBD + 123
        print(f"m = {m}")
        c = nhan_bpl(m, e, n)
        print(f"c = {c}")
        m = nhan_bpl(c, d, n)
        print(f"m = {m}")
    except ValueError as e:
        print(e)
# Out:
# 197 157
# p = 197, q = 157
# n = 30929
# U = 30576
# e = 6299
# d = 28979
# m = 335
# c = 13254
# m = 335

# %% [markdown]
# # Câu 33

# %% [markdown]
# # Câu 34

# %%
from random import *

def nhan_binh_phuong_lap(a, k, n):
    b = 1
    A = a % n 

    while k > 0:
        if k & 1 == 1:
            b = (b * A) % n
        k >>= 1
        A = (A * A) % n

    return b

def is_prime_fermat(n, t):
    for i in range(t):
        a = randint(2, n - 1)
        r = nhan_binh_phuong_lap(a, n - 1, n)
        if r != 1:
            return False
    return True

if __name__ == '__main__':
    try:
        n, t = map(int, input("Nhập n và t: ").split())
        if n < 3 or t < 1:
            raise ValueError("Không hợp lệ!")
        if n % 2 == 0: 
            print(f'{n} không là số nguyên tố')
        if is_prime_fermat(n, t):
            print(f'{n} là số nguyên tố')
        else:
            print(f'{n} không là số nguyên tố')
    except ValueError as e:
        print(e)
# Out:
# Không hợp lệ!

# %% [markdown]
# # Câu 35

# %%
from math import *
from random import *
def find_s_r(n):
    n -= 1
    s = 0
    while(n % 2 == 0):
        n //= 2
        s += 1
    r = n
    return s, r

def nhan_binh_phuong_lap(a, k, n):
    b = 1
    A = a % n 

    while k > 0:
        if k & 1 == 1:
            b = (b * A) % n
        k >>= 1
        A = (A * A) % n
    return b


def is_prime_miller_rabin(n, t):
    s, r = find_s_r(n)
    for i in range(t):
        a = randint(2, n - 1)
        y =  nhan_binh_phuong_lap(a, r, n)
        if y != 1 and y != n - 1:
            j = 1
            while j <= 𝑠 - 1 and y != n - 1:
                y = y ** 2 % n
                if y == 1:
                    return False
                j += 1
            if y != n - 1 :
                return False
    return True
        
if __name__ == '__main__':
    try:
        n, t = map(int, input("Nhập n và t: ").split())
        if n < 3 or t < 1:
            raise ValueError("Không hợp lệ!")
        if n % 2 == 0:
            print(f'{n} là hợp số')
        elif is_prime_miller_rabin(n, t):
            print(f'{n} là số nguyên tố') 
            print(f"Xác suất đúng: p = ", 1 - 0.25**t)      
        else:
            print(f'{n} là hợp số')
    except ValueError as e:
        print(e)
# Out:
# 5 là số nguyên tố
# Xác suất đúng: p =  0.984375

# %% [markdown]
# # Câu 36

# %%
def last_occurrence(p, kitu):
    for i in range(len(p) - 1, -1, -1):
        if kitu == p[i]:
            return i
    return -1

def xu_ly(t, p):
    m, n = len(p), len(t)
    i, j = m - 1, m - 1
    check = 0
    sopheptinh = 0

    while i < n:
        checkp = 0
        while checkp != m:
            if t[i] == p[j]:
                i -= 1
                j -= 1
                checkp += 1
                sopheptinh += 1
            else:
                last_occ = last_occurrence(p, t[i])
                i += m - min(j, 1 + last_occ)
                j = m - 1
                sopheptinh += 1
                break

        if checkp == m:
            check += 1
            print(f"\nKQ: Vi tri {i + 1}")
            break
            

    if check == 0:
        print("\nKQ: Khong co chuoi can tim")
    else:
        print(f"\nSo phep tinh la: {sopheptinh}")
if __name__ == "__main__":
    t = input("Nhap doan van ban T: ")
    p = input("Nhap chuoi P can tim: ")
    xu_ly(t, p)

# %% [markdown]
# # Câu 37

# %%
def failureFunction(p):
    f = [-1, 0]
    for j in range(2, len(p)):
        i = f[j - 1]
        while i >= 0 and p[i] != p[j - 1]:
            i = f[i]
        f.append(i + 1)
    return f

def xuLy(t, p, f):
    i = 0
    j = 0
    check = 0
    sopheptinhlap = 0
    while i < len(t) - len(p):
        checkp = j
        k = i + j
        while checkp != len(p):
            if t[k] == p[j]:
                k += 1
                j += 1
                checkp += 1
                sopheptinhlap += 1
            else:
                i = i + j - f[j]
                j = 0 if f[j] == -1 else f[j]
                sopheptinhlap += 1
                break
        if checkp == len(p):
            print(f"\nKQ: Vi tri {i}")
            check = 1
            j = 0
            i = i + len(p)
    if check == 0:
        print("\nKQ: Khong co chuoi can tim")
    return sopheptinhlap

if __name__ == "__main__":
    t = input("Nhap doan van ban T: ")
    p = input("Nhap chuoi P can tim: ")
    print(f"Văn bản: {t}")
    print(f"Chuỗi cần kiểm tra: {p}")
    f = failureFunction(p)
    sopheptinhlap = xuLy(t, p, f)
    print(f"\nSo phep tinh lap la: {sopheptinhlap}")
# Out:
# Văn bản: xin choa viet nam
# Chuỗi cần kiểm tra: na
#
# KQ: Vi tri 14
#
# So phep tinh lap la: 17

# %% [markdown]
# # Câu 38

# %%
def gcd(a, b):
    while b != 0:
        a, b = b, a % b
    return a

def xu_ly(a, p):
    if gcd(a, p) != 1:
        print(f"Không có nghịch đảo của {a} modulo {p} vì chúng không nguyên tố cùng nhau.")
        return
    
    u = a
    v = p
    x1 = 1
    x2 = 0
    
    while u != 1:
        q = v // u
        r = v - q * u
        x = x2 - q * x1
        v = u
        u = r
        x2 = x1
        x1 = x
    
    if x1 < 0:
        x1 = x1 + p
    
    print(f"\n{a} ^ -1 mod {p} = {x1}")

def main():
    a = int(input("Nhập a: "))
    p = int(input("Nhập p: "))
    xu_ly(a, p)

if __name__ == "__main__":
    main()
# Out:
# 4 ^ -1 mod 7 = 2

# %% [markdown]
# # Câu 39

# %%
def create_array():
    a = input("Nhập mảng: ").split()
    return [int(x) for x in a]

def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

def gcd(a, b):
    while b > 0:
        a, b = b, a % b
    return a

def pairs(array):
    pairs = []
    l = len(array)
    for i in range(l - 1):
        for j in range(i + 1, l):
            if is_prime(gcd(a[i], a[j])):
                pairs.append((a[i], a[j]))
    return pairs

if __name__ == '__main__':
    try:
        a = create_array()
        for x in range(len(a)):
            if a[x] < 0:
                raise ValueError("Không hợp lệ!")
        print(f"a = {a}")
        pairs = pairs(a)
        if not pairs:
            print("Không có cặp số thỏa mãn")
        else:
            print("Các cặp số là: ")
            for x in pairs:
                print(x)
    except ValueError as e:
        print(e)
# Out:
# a = [2, 23, 17, 19, 32, 31, 93, 73, 54, 11, 25]
# Các cặp số là:
# (2, 32)
# (2, 54)
# (32, 54)
# (31, 93)
# (93, 54)

# %% [markdown]
# # Câu 40

# %%
def create_array():
    a = input("Nhập mảng: ").split()
    return [int(x) for x in a]

def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

def gcd(a, b):
    while b > 0:
        a, b = b, a % b
    return a

def count_pairs(array):
    count = 0
    l = len(array)
    for i in range(l - 1):
        for j in range(i + 1, l):
            if is_prime(gcd(a[i], a[j])):
                count += 1
    return count



if __name__ == '__main__':
    try:
        a = create_array()
        for x in range(len(a)):
            if a[x] < 0:
                raise ValueError("Không hợp lệ!")
        print(f"a = {a}")
        count = count_pairs(a)
        print(f"Số các cặp số (i,j) thỏa mãn: {count} ")
    except ValueError as e:
        print(e)
# Out:
# a = [4, 8, 16]
# Số các cặp số (i,j) thỏa mãn: 0

# %% [markdown]
# # Câu 41

# %%
def nhan_bpl(a, k, n):
    b = 1
    A = a % n  

    while k > 0:
        if k & 1 == 1:
            b = b * A % n
        k >>= 1
        A = A * A % n
    return b

def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

if __name__ == '__main__':
    try:
        a, k, n = map(int, input("Nhập: ").split())
        if not 0 < k < n < 1000 or not 0 < a < n < 1000:
            raise ValueError("Không hợp lệ!")
        result = nhan_bpl(a, k, n)
        if is_prime(result):
            print("Là số nguyên tố")
        else: 
            print("Không là số nguyên tố")  
    except ValueError as e:
        print(e)
# Out:
# Không là số nguyên tố

# %% [markdown]
# # Câu 42

# %%
import random

def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

def generate_prime():
    while True:
        num = random.randint(2, 1000)
        if is_prime(num):
            return num
        
def nhan_bpl(a, k, n):
    b = 1
    A = a % n  

    while k > 0:
        if k & 1 == 1:
            b = b * A % n
        k >>= 1
        A = A * A % n
    return b

def main():
    p = generate_prime()
    q = generate_prime()
    
    print(f"p = {p}, q = {q}")
    
    valid_a = []
    for a in range(0, 100):
        result = nhan_bpl(a, p, q)
        if is_prime(result):
            valid_a.append(a)
    
    print("Số nguyên a thỏa mãn là: ", valid_a)

if __name__ == "__main__":
    main()
# Out:
# p = 433, q = 991
# Số nguyên a thỏa mãn là:  [10, 14, 29, 33, 35, 38, 40, 41, 42, 44, 45, 57, 65, 69, 84, 96]

# %% [markdown]
# # Câu 43

# %%
from math import *

def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

def generate_prime():
    while True:
        num = randint(2, 100)
        if is_prime(num):
            return num
        
def nhan_bpl(a, k, n):
    b = 1
    A = a % n  

    while k > 0:
        if k & 1 == 1:
            b = b * A % n
        k >>= 1
        A = A * A % n
    return b


if __name__ == "__main__":
    try: 
        N = int(input("Nhập N: "))
        if not 0 < N < 1000: 
            raise ValueError("Không hợp lệ!")
        p = generate_prime()
        print(f"p = {p}")
        
        valid_a = []
        for a in range(0, 100):
            result = nhan_bpl(a, p, N)
            if is_prime(result):
                valid_a.append(a)
        print("Số nguyên a thỏa mãn là: ", valid_a)
    except ValueError as e:
        print(e)
# Out:
# p = 53
# Số nguyên a thỏa mãn là:  [3, 7, 13, 17, 19, 21, 23, 27, 29, 31, 35, 39, 45, 49, 51, 53, 55, 59, 61, 63, 67, 71, 77, 81, 83, 85, 87, 91, 93, 95, 99]

# %% [markdown]
# # Câu 44

# %%
def create_array():
    a = input("Nhập mảng: ").split()
    return [int(x) for x in a]

def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

def gcd(a, b):
    while b > 0:
        a, b = b, a % b
    return a

def nghicdao(a, p):
   
    u = a
    v = p
    x1 = 1
    x2 = 0
    
    while u != 1:
        q = v // u
        r = v - q * u
        x = x2 - q * x1
        v = u
        u = r
        x2 = x1
        x1 = x
    
    if x1 < 0:
        x1 = x1 + p
    
    return x1
    

if __name__ == '__main__':
    try:
        p = int(input("Nhập p: "))
        
        while True:
            a = create_array()
            is_valid = True
            for x in a:
                if gcd(x, p) != 1 or x > p:
                    is_valid = False
                    break
            if is_valid:
                break

        print(f"A = {a}")
        b = []
        for x in a:
            b.append(nghicdao(x, p))
        print(f"B = {b}")
    except ValueError as e:
        print(e)
# Out:
# A = [11, 3, 2, 5]
# B = [158990, 64774, 97161, 155457]

# %% [markdown]
# # Câu 45

# %%
from random import *

def find_s_r(n):
    n -= 1
    s = 0
    while(n % 2 == 0):
        n //= 2
        s += 1
    r = n
    return s, r

def nhan_binh_phuong_lap(a, k, n):
    b = 1
    A = a % n  # Giảm số lượng lần lặp

    while k:
        if k & 1 == 1:
            b = (b * A) % n
        k >>= 1
        A = (A * A) % n
    return b


def is_prime_miller_rabin(n, t):
    s, r = find_s_r(n)
    for i in range(t):
        a = randint(2, n - 2)
        y =  nhan_binh_phuong_lap(a, r, n)
        if y != 1 and y != n - 1:
            j = 1
            while j <= 𝑠 - 1 and y != n - 1:
                y = y ** 2 % n
                if y == 1:
                    return False
                j += 1
            if y != n - 1 :
                return False
    return True

def generate_prime():
    while True:
        num = randint(2, 1000)
        if is_prime_miller_rabin(num, 5):
            return num
        
def add_prime(N):
    arr = []
    for i in range(N):
        arr.append(generate_prime())
    return arr

def min_diff(primes):
    min_distance = float('inf')
    for i in range(len(primes) - 1):
        for j in range(i + 1, len(primes)):
            temp = abs(primes[i] - primes[j])
            if temp < min_distance:
                min_distance = temp
    return min_distance
        
if __name__ == '__main__':
    try:
        N = int(input("Nhập N: "))
        if N < 2:
            raise ValueError("Không hợp lệ!")
        primes = add_prime(N)
        min = min_diff(primes)
        print(primes)
        print(f"khoảng cách nhỏ nhất giữa 2 số bất kỳ trong mảng: {min}")
    except ValueError as e:
        print(e)
# Out:
# [11, 269, 719, 769]
# khoảng cách nhỏ nhất giữa 2 số bất kỳ trong mảng: 50
